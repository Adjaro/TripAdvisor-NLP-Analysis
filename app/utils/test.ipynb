# %%
import json

# %%
# !pip  freeze
# lire tous  les  ficher  json  de  data  
# 1-  lire  le  contenu  de  chaque  fichier  json
# 2-  afficher  le  contenu  de  chaque  fichier  json
# 3-  afficher  le  nom  de  chaque  fichier  json
# 4-  afficher  le  nombre  de  fichier  json
# 5-  afficher  le  nombre  total  de  ligne  de  chaque  fichier  json
# 6-  afficher  le  nombre  total  de  ligne  de  tous  les  fichier  json
# 7-  afficher  le  nombre  total  de  mot  de  chaque  fichier  json
# 8-  afficher  le  nombre  total  de  mot  de  tous  les  fichier  json
# 9-  afficher  le  nombre  total  de  caractere  de  chaque  fichier  json
# 10-  afficher  le  nombre  total  de  caractere  de  tous  les  fichier  json

import os
import json
import re
import string

def read_json_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# %%
# workdir
import os
affiche = os.getcwd()
print(affiche)
# Out:
# c:\Users\ediad\Documents\NLP\TripAdvisor-NLP-Analysis\app\utils

# %%
# liste  des  fichiers  json de /data
data_dir = '../data'
json_files = [f for f in os.listdir(data_dir) if f.endswith('.json')]
# Out:
# ['Agastache_Restaurant.json', 'Aromatic_Restaurant.json', 'BLO_Restaurant.json', 'Bouchon_Les_Lyonnais.json', 'Chez_Antonin.json', 'Chez_Micheline.json', 'Copains_Copines_Sur_la_Colline.json', 'Frazarin_Bistrot_Franco_Italien.json', 'LActeur.json', 'Laffreux_Jojo.json', 'La_Criee.json', 'La_Table_de_Max.json', 'Les_3_Dômes.json', 'Le_Conde.json', 'Le_Desjeuneur.json', 'Le_Grand_Réfectoire.json', 'Le_Palais_Saint_Jean.json', 'Le_Vieux_Lyon.json', 'LInstitution.json', 'LInstitut_Restaurant.json', 'Mama_Restaurant_Lyon.json', 'Monsieur_P.json', 'Restaurant_Le_Musée.json', 'Restaurant_Lounge_N133.json', 'Restaurant_Opaline.json']

# %%
import os
import json
import re
import string
from model import schemas

def read_json_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)
    
data_dir = '../data'
json_files = [f for f in os.listdir(data_dir) if f.endswith('.json')]



for  file  in  json_files[:1]:
    print(file)
    file_path = os.path.join(data_dir, file)
    data = read_json_file(file_path)
    print(data ['avis'])
    # print(len(data))
# Out:
# Agastache_Restaurant.json
# ...
